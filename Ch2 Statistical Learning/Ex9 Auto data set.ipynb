# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
# !head ../Data/Auto.csv
# Out:
# mpg,cylinders,displacement,horsepower,weight,acceleration,year,origin,name
# 18,8,307,130,3504,12,70,1,chevrolet chevelle malibu
# 15,8,350,165,3693,11.5,70,1,buick skylark 320
# 18,8,318,150,3436,11,70,1,plymouth satellite
# 16,8,304,150,3433,12,70,1,amc rebel sst
# 17,8,302,140,3449,10.5,70,1,ford torino
# 15,8,429,198,4341,10,70,1,ford galaxie 500
# 14,8,454,220,4354,9,70,1,chevrolet impala
# 14,8,440,215,4312,8.5,70,1,plymouth fury iii
# 14,8,455,225,4425,10,70,1,pontiac catalina

# %%
# Remove the lines with missing values
auto = pd.read_csv("../Data/Auto.csv", na_values="?").dropna()
auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 396
# Data columns (total 9 columns):
# mpg             392 non-null float64
# cylinders       392 non-null int64
# displacement    392 non-null float64
# horsepower      392 non-null float64
# weight          392 non-null int64
# acceleration    392 non-null float64
# year            392 non-null int64
# origin          392 non-null int64
# name            392 non-null object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 30.6+ KB

# %%
interesting_statistics = ['min', 'max', 'mean', 'std']
auto.describe().loc[interesting_statistics]
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# min    9.000000   3.000000     68.000000   46.000000  1613.000000
# max   46.600000   8.000000    455.000000  230.000000  5140.000000
# mean  23.445918   5.471939    194.411990  104.469388  2977.584184
# std    7.805007   1.705783    104.644004   38.491160   849.402560
#
#       acceleration       year    origin
# min       8.000000  70.000000  1.000000
# max      24.800000  82.000000  3.000000
# mean     15.541327  75.979592  1.576531
# std       2.758864   3.683737  0.805518

# %%
subset = auto.iloc[10:85]
subset.describe().loc[interesting_statistics]
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# min    9.000000   3.000000     70.000000   46.000000  1613.000000
# max   35.000000   8.000000    455.000000  225.000000  5140.000000
# mean  19.520000   5.853333    222.020000  119.120000  3141.280000
# std    6.156429   1.857733    118.558471   44.989176   982.598383
#
#       acceleration       year    origin
# min       8.000000  70.000000  1.000000
# max      23.500000  73.000000  3.000000
# mean     14.853333  71.146667  1.480000
# std       2.834123   0.816938  0.741802

# %%
sns.pairplot(auto.iloc[:,0:7]);

# %% [markdown]
# *mpg* is negatively correlated with *cylinders*, *displacement*, *horsepower* and *weight* and positively correlated with *year*.
